# %%
print("-------------------------------------------- WELCOME TO THE CRICKET MATCH ! -------------------------------------------")

team_1 = input("\nEnter the name of first team: ")

print("\n\t\t\t\t\tWELCOME! {}".format(team_1.upper()))

team_2 = input("\nEnter the name of second team: ")

print("\n\t\t\t\t\tWELCOME! {}".format(team_2.upper()))

team_a = []
team_b = []
top_stats={}

no_of_players = input("\nEnter the number of players in each team: ")
no_of_players = int(no_of_players)

n = 1
print("\nEnter the names of players for {}:".format(team_1.upper()))

while n <= no_of_players:
    
    player_name_a = input("Player Name: ")
    team_a.append(player_name_a)
    n+=1
    
print("\n{} : ".format(team_1.upper()))

for player_a in team_a:
    
    print("\t{}".format(player_a.title()))
n=1

print("\nEnter the names of player for {}: ".format(team_2.upper()))

while n <= no_of_players:
    
    player_name_b=input("Player name: ")
    team_b.append(player_name_b)
    n+=1

print("\n{} : ".format(team_2.upper()))

for player_b in team_b:
    
    print("\t{}".format(player_b.title()))
    
no_of_overs = input("\nEnter the number of overs to be played: \n")
no_of_overs = int(no_of_overs)

no_of_balls = no_of_overs*6

print("--------------------------------------------------> MATCH STARTS ! <--------------------------------------------------")

nob = no_of_balls
runs_a = 0
wickets_a = 0

print("\nTOSS TIME.... ")
outcome=input("\nEnter 'H' for HEADS and 'T' for TAILS : ")
m=1

if outcome == 'H':
    
    print("\n\t\t\t\t\t{} won the toss!! ".format(team_1.upper()))
    print("\t\t\t\t\tThey chose to BAT first !!")
    
    print("\nNo.of balls remaining: {}".format(nob))
    print("\n\t\t\t\t\t\t{}: {} - {} ".format(team_1.upper(),runs_a,wickets_a))
    
    
    while m <= nob:
        
        if m == 1:
            
            print("\n{}st ball of the innings...".format(m))
            
            input_runs_a=input("Runs: ")
            input_runs_a=int(input_runs_a)
            
            if input_runs_a < 0 or input_runs_a == 5 or input_runs_a > 6:
                print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                continue
                
            elif input_runs_a == 6:
                print("That was a great shot... you hit a 6 !!")
                
            elif input_runs_a == 4:
                print("Nice shot... you scored 4 !!")
                
            runs_a = runs_a + input_runs_a
            print("\n\t\t\t\t\t\t{} : {} - {}".format(team_1.upper(),runs_a,wickets_a))
            m += 1
            
        elif m % 9 == 0:
            
            print("\nNext ball....")
            
            input_runs_a = input("RUNS: ")
            input_runs_a = int(input_runs_a)
            
            if input_runs_a < 0 or input_runs_a == 5 or input_runs_a > 6:
                
                print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                continue
                
            print("\n{} lost a wicket ! ....".format(team_1.upper()))
            
            wickets_a += 1
            
            print("\n\t\t\t\t\t\t{} : {} - {}".format(team_1.upper(),runs_a,wickets_a))
            
            if wickets_a < no_of_players:
                m += 1
                continue
            elif wickets_a >= no_of_players:
                print("{} lost all its wickets! ...".format(team_1.upper()))
                break
                
                
            m += 1
            
        else:
            
            print("\nNext ball....")
            
            input_runs_a = input("RUNS: ")
            input_runs_a = int(input_runs_a)
            
            if input_runs_a < 0 or input_runs_a == 5 or input_runs_a > 6:
                print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                continue
                
            elif input_runs_a == 6:
                print("That was a great shot... you hit a 6 !!")
                
            elif input_runs_a == 4:
                print("Nice shot... you scored 4 !!")
                
            runs_a = runs_a + input_runs_a
            print("\n\t\t\t\t\t\t{} : {} - {}".format(team_1.upper(),runs_a,wickets_a))
            m += 1
            
    print("\t\t\t\t\tFIRST INNINGS OVER....")
    print("\n{} score after 1st innings is....".format(team_1.upper()))
    print("\n\t\t\t\t\t\t{}: {} - {}".format(team_1.upper(),runs_a,wickets_a))
    print("\n\n\t\t\t\t\t\t{} need {} to win of {} overs".format(team_2.upper(),runs_a+1,no_of_overs))
    
    print("\n\t\t\t\t\tSECOND INNINGS....")
    no_of_balls = no_of_overs*6 
    nob = no_of_balls
    runs_b = 0
    wickets_b = 0
    m = 1

    while m <= nob :
    
        
            if m == 1:
            
                print("\n{}st ball of the innings...".format(m))
            
                input_runs_b=input("Runs: ")
                input_runs_b=int(input_runs_b)
            
                if input_runs_b < 0 or input_runs_b == 5 or input_runs_b > 6:
                    print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                    continue
                
                elif input_runs_b == 6:
                    print("That was a great shot... you hit a 6 !!")
                
                elif input_runs_b == 4:
                    print("Nice shot... you scored 4 !!")
                
                runs_b = runs_b + input_runs_b
                print("\n\t\t\t\t\t\t{} : {} - {}".format(team_2.upper(),runs_b,wickets_b))
            
                m += 1
            
    
            elif m % 7 == 0:
            
                print("\nNext ball....")
            
                input_runs_b = input("RUNS: ")
                input_runs_b = int(input_runs_b)
            
                if input_runs_b < 0 or input_runs_b == 5 or input_runs_b > 6:
                
                    print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                    continue
                
                print("\n{} lost a wicket! ....".format(team_2.upper()))
            
                wickets_b += 1
            
                print("\n\t\t\t\t\t\t{} : {} - {}".format(team_2.upper(),runs_b,wickets_b))
            
                if wickets_b < no_of_players:
                    m += 1
                    continue
                elif wickets_b >= no_of_players:
                    print("{} lost all its wickets! ....".format(team_2.upper()))
                    break
                
                m += 1
            
            elif runs_b > runs_a :
                print("{} won by {} wickets".format(team_2.upper(),no_of_players-wickets_b))
                print("\n\t\t\t\t\t\tCONGO {} !!!!".format(team_2.upper()))
                print("-----------------------------------------------X----MATCH ENDS----X------------------------------------------------------")
                break
                
            else:
            
                print("\nNext ball....")
            
                input_runs_b = input("RUNS: ")
                input_runs_b = int(input_runs_b)
            
                if input_runs_b < 0 or input_runs_b == 5 or input_runs_b > 6:
                    print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                    continue
                
                elif input_runs_b == 6:
                    print("That was a great shot... you hit a 6 !!")
                
                elif input_runs_b == 4:
                    print("Nice shot... you scored 4 !!")
                
                runs_b = runs_b + input_runs_b
                print("\n\t\t\t\t\t\t{} : {} - {}".format(team_2.upper(),runs_b,wickets_b))
            
                m += 1
            
if runs_a > runs_b :
    print("{} won by {} runs".format(team_1.upper(),runs_a-runs_b))
    print("\n\t\t\t\t\t\tCONGO {} !!!!".format(team_1.upper()))
    print("-----------------------------------------------X----MATCH ENDS----X------------------------------------------------------")


if outcome=='T':
    
    print("\n\t\t\t\t\t{} won the toss!! ".format(team_2.upper()))
    print("\t\t\t\t\tThey chose to FIELD first !!")
    
    print("\nNo.of balls remaining: {}".format(nob))
    print("\n\t\t\t\t\t{}: {} - {} ".format(team_1.upper(),runs_a,wickets_a))
    
    
    while m <= nob:
        
        if m == 1:
            
            print("\n{}st ball of the innings...".format(m))
            
            input_runs_a=input("Runs: ")
            input_runs_a=int(input_runs_a)
            
            if input_runs_a < 0 or input_runs_a == 5 or input_runs_a > 6:
                print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                continue
                
            elif input_runs_a == 6:
                print("That was a great shot... you hit a 6 !!")
                
            elif input_runs_a == 4:
                print("Nice shot... you scored 4 !!")
                
            runs_a = runs_a + input_runs_a
            print("\n\t\t\t\t\t{} : {} - {}".format(team_1.upper(),runs_a,wickets_a))
            m += 1
            
        elif m % 9 == 0:
            
            print("\nNext ball....")
            
            input_runs_a = input("RUNS: ")
            input_runs_a = int(input_runs_a)
            
            if input_runs_a < 0 or input_runs_a == 5 or input_runs_a > 6:
                
                print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                continue
                
            print("\nOops... You lost a wicket..")
            
            wickets_a += 1
            
            print("\n\t\t\t\t\t{} : {} - {}".format(team_1.upper(),runs_a,wickets_a))
            
            if wickets_a < no_of_players:
                m += 1
                continue
            elif wickets_a >= no_of_players:
                print("You lost all your wickets...")
                break
                
                
            m += 1
            
        else:
            
            print("\nNext ball....")
            
            input_runs_a = input("RUNS: ")
            input_runs_a = int(input_runs_a)
            
            if input_runs_a < 0 or input_runs_a == 5 or input_runs_a > 6:
                print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                continue
                
            elif input_runs_a == 6:
                print("That was a great shot... you hit a 6 !!")
                
            elif input_runs_a == 4:
                print("Nice shot... you scored 4 !!")
                
            runs_a = runs_a + input_runs_a
            print("\n\t\t\t\t\t{} : {} - {}".format(team_1.upper(),runs_a,wickets_a))
            m += 1
            
    print("\t\t\t\t\t\tFIRST INNINGS OVER....")
    print("\n{} score after 1st innings is....".format(team_1.upper()))
    print("\n\t\t\t\t\t{}: {} - {}".format(team_1.upper(),runs_a,wickets_a))
    print("\n\n\t\t\t\t\t{} need {} to win of {} overs".format(team_2.upper(),runs_a+1,no_of_overs))
    
    print("\n\t\t\t\t\t\tSECOND INNINGS....")
    no_of_balls = no_of_overs*6 
    nob = no_of_balls
    runs_b = 0
    wickets_b = 0
    m = 1

    while m <= nob :
    
        
            if m == 1:
            
                print("\n{}st ball of the innings...".format(m))
            
                input_runs_b=input("Runs: ")
                input_runs_b=int(input_runs_b)
            
                if input_runs_b < 0 or input_runs_b == 5 or input_runs_b > 6:
                    print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                    continue
                
                elif input_runs_b == 6:
                    print("That was a great shot... you hit a 6 !!")
                
                elif input_runs_b == 4:
                    print("Nice shot... you scored 4 !!")
                
                runs_b = runs_b + input_runs_b
                print("\n\t\t\t\t\t{} : {} - {}".format(team_2.upper(),runs_b,wickets_b))
            
                m += 1
            
    
            elif m % 7 == 0:
            
                print("\nNext ball....")
            
                input_runs_b = input("RUNS: ")
                input_runs_b = int(input_runs_b)
            
                if input_runs_b < 0 or input_runs_b == 5 or input_runs_b > 6:
                
                    print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                    continue
                
                print("\nOops... You lost a wicket..")
            
                wickets_b += 1
            
                print("\n\t\t\t\t\t{} : {} - {}".format(team_2.upper(),runs_b,wickets_b))
            
                if wickets_b < no_of_players:
                    m += 1
                    continue
                elif wickets_b >= no_of_players:
                    print("You lost all your wickets...")
                    break
                
                m += 1
            
            elif runs_b > runs_a :
                print("\t\t\t\t\t\t{} won by {} wickets".format(team_2.upper(),no_of_players-wickets_b))
                print("\n\t\t\t\t\tCONGO {} !!!!".format(team_2.upper()))
                print("---------------------------------------------X----MATCH ENDS----X------------------------------------------------------")
                break
                
            else:
            
                print("\nNext ball....")
            
                input_runs_b = input("RUNS: ")
                input_runs_b = int(input_runs_b)
            
                if input_runs_b < 0 or input_runs_b == 5 or input_runs_b > 6:
                    print("\nWe cant score negative, 5 or runs greater than 6 on a single ball :)")
                    continue
                
                elif input_runs_b == 6:
                    print("That was a great shot... you hit a 6 !!")
                
                elif input_runs_b == 4:
                    print("Nice shot... you scored 4 !!")
                
                runs_b = runs_b + input_runs_b
                print("\n\t\t\t\t\t{} : {} - {}".format(team_2.upper(),runs_b,wickets_b))
            
                m += 1
            
if runs_a > runs_b :
    print("\t\t\t\t\t\t{} won by {} runs".format(team_1.upper(),runs_a-runs_b))
    print("\n\t\t\t\t\t\tCONGO {} !!!!".format(team_1.upper()))
    print("\n\n---------------------------------------------X----MATCH ENDS----X------------------------------------------------------")
# Out:
# -------------------------------------------- WELCOME TO THE CRICKET MATCH ! -------------------------------------------
#
# Enter the name of first team: aa
#
# 					WELCOME! AA
#
# Enter the name of second team: ss
#
# 					WELCOME! SS
#
# Enter the number of players in each team: 2
#
# Enter the names of players for AA:
# Player Name: q
# Player Name: w
#
# AA :
# 	Q
# 	W
#
# Enter the names of player for SS:
# Player name: d
# Player name: r
#
# SS :
# 	D
# 	R
#
# Enter the number of overs to be played:
# 2
# --------------------------------------------------> MATCH STARTS ! <--------------------------------------------------
#
# TOSS TIME....
#
# Enter 'H' for HEADS and 'T' for TAILS : T
#
# 					SS won the toss!!
# 					They chose to FIELD first !!
#
# No.of balls remaining: 12
#
# 					AA: 0 - 0
#
# 1st ball of the innings...
# Runs: 2
#
# 					AA : 2 - 0
#
# Next ball....
# RUNS: 2
#
# 					AA : 4 - 0
#
# Next ball....
# RUNS: 1
#
# 					AA : 5 - 0
#
# Next ball....
# RUNS: 1
# ...

# %% [markdown]
# ######
